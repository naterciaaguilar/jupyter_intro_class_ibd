# %% [markdown]
# ## Jupyter e Pandas

# %% [markdown]
# Pandas é uma biblioteca open source que fornece estruturas de dados de alto desempenho e fáceis de usar e ferramentas de análise de dados para a linguagem de programação Python.
#
# * Pandas: https://pandas.pydata.org/
# * Documentação: http://pandas.pydata.org/pandas-docs/stable/
# * Tutoriais: https://pandas.pydata.org/pandas-docs/stable/getting_started/tutorials.html

# %%
import pandas as pd

# %% [markdown]
# ### Importando um dataframe a partir de um arquivo

# %%
df = pd.read_csv("../data/music_data.csv")
df.head()
# Out:
#    id_billboard                                song_name            artist  \
# 0            71  Sorry - Originally performed by Beyonce  2016 Dynamo Hitz
# 1             7                                    Hello             Adele
# 2            26         Send My Love (To Your New Lover)             Adele
# 3            83                       When We Were Young             Adele
# 4            39                                     Here      Alessia Cara
#
#                                               lyrics  danceability  energy  \
# 0                                                NaN         0.699   0.526
# 1  Hello, it's me I was wondering if after all th...         0.481   0.451
# 2  Just the guitar. OK, cool. This was all you, n...         0.690   0.524
# 3                                                NaN         0.381   0.594
# 4                                                NaN         0.376   0.810
#
#    key  loudness  mode  speechiness       ...        instrumentalness  \
# 0    2   -13.514     1       0.0373       ...                0.001650
# 1    5    -6.095     0       0.0347       ...                0.000000
# 2    6    -8.390     0       0.1030       ...                0.000003
# 3    3    -5.970     1       0.0486       ...                0.000000
# 4    0    -4.003     1       0.1660       ...                0.000000
#
#    liveness  valence     time            type                      id  \
# 0    0.1930    0.148  129.980  audio_features  5rzLBhiS7SJy03ZfcTpUSy
# 1    0.0872    0.287  157.966  audio_features  4sPmO7WMQUAf45kwMOtONw
# 2    0.1700    0.561  164.023  audio_features  4BHzQ9C00ceJxfG16AlNWb
# 3    0.0925    0.275  143.860  audio_features  7IWkJwX9C0J7tHurTD7ViL
# 4    0.0730    0.334  123.909  audio_features  664gdARxaClFsoF5SXKOws
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5rzLBhiS7SJy...
# 1  https://api.spotify.com/v1/tracks/4sPmO7WMQUAf...
# 2  https://api.spotify.com/v1/tracks/4BHzQ9C00ceJ...
# 3  https://api.spotify.com/v1/tracks/7IWkJwX9C0J7...
# 4  https://api.spotify.com/v1/tracks/664gdARxaClF...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5rzL...      232934
# 1  https://api.spotify.com/v1/audio-analysis/4sPm...      295493
# 2  https://api.spotify.com/v1/audio-analysis/4BHz...      223080
# 3  https://api.spotify.com/v1/audio-analysis/7IWk...      290907
# 4  https://api.spotify.com/v1/audio-analysis/664g...      199453
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 21 columns]

# %% [markdown]
# * As colunas do dataframe são um atributo do objeto

# %%
df.columns
# Out:
# Index(['id_billboard', 'song_name', 'artist', 'lyrics', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'time', 'type', 'id',
#        'track_href', 'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %% [markdown]
# * Também podem ser visualizados atributos e dados gerais

# %%
df[['danceability', 'energy', 'loudness']].describe()
# Out:
#        danceability     energy  loudness
# count     60.000000  60.000000  60.00000
# mean       0.659200   0.644883  -6.19370
# std        0.132919   0.154437   2.39571
# min        0.376000   0.275000 -13.51400
# 25%        0.573250   0.558000  -7.53325
# 50%        0.655500   0.670500  -5.72650
# 75%        0.758250   0.761000  -4.66275
# max        0.916000   0.928000  -2.78700

# %% [markdown]
# ### Removendo colunas do dataset original
#
# As colunas de um dataframe podem ser removidas utilizando o label ou os índices

# %%
new_df = df.drop(['key', 'mode', 'time', 'track_href', 'analysis_url', 'time_signature', 'id', 'type'], axis=1)
new_df.head()
# Out:
#    id_billboard                                song_name            artist  \
# 0            71  Sorry - Originally performed by Beyonce  2016 Dynamo Hitz
# 1             7                                    Hello             Adele
# 2            26         Send My Love (To Your New Lover)             Adele
# 3            83                       When We Were Young             Adele
# 4            39                                     Here      Alessia Cara
#
#                                               lyrics  danceability  energy  \
# 0                                                NaN         0.699   0.526
# 1  Hello, it's me I was wondering if after all th...         0.481   0.451
# 2  Just the guitar. OK, cool. This was all you, n...         0.690   0.524
# 3                                                NaN         0.381   0.594
# 4                                                NaN         0.376   0.810
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   -13.514       0.0373       0.00101          0.001650    0.1930    0.148
# 1    -6.095       0.0347       0.33600          0.000000    0.0872    0.287
# 2    -8.390       0.1030       0.04150          0.000003    0.1700    0.561
# 3    -5.970       0.0486       0.34800          0.000000    0.0925    0.275
# 4    -4.003       0.1660       0.08440          0.000000    0.0730    0.334
#
#    duration_ms
# 0       232934
# 1       295493
# 2       223080
# 3       290907
# 4       199453

# %% [markdown]
# ### Acesso por colunas

# %% [markdown]
# * Acessando uma única coluna

# %%
new_df['artist']
# Out:
# 0                                      2016 Dynamo Hitz
# 1                                                 Adele
# 2                                                 Adele
# 3                                                 Adele
# 4                                          Alessia Cara
# 5                                         Ariana Grande
# 6                                         Ariana Grande
# 7                             Ariana Grande Nicki Minaj
# 8                                         Bryson Tiller
# 9                                         Bryson Tiller
# 10                                Calvin Harris Rihanna
# 11                                         Charlie Puth
# 12                            Charlie Puth Selena Gomez
# 13                                          Chris Brown
# 14                                             Coldplay
# 15                                        Coldplay Seeb
# 16                                                 Daya
# 17                                                 Daya
# 18                                            Desiigner
# 19                                            Desiigner
# 20                                      DJ Khaled Drake
# 21                            DJ Snake Bipolar Sunshine
# 22                               DJ Snake Justin Bieber
# 23                                                 DNCE
# 24                                                Drake
# 25                                                Drake
# 26                                         Drake Future
# 27                                        Drake Rihanna
# 28                                     Drake The Throne
# 29                                    Drake WizKid Kyla
# 30                                      DRAM Lil Yachty
# 31                                            Elle King
# 32                                       Ellie Goulding
# 33         Fat Joe Remy Ma JAY Z French Montana InfaRed
# 34                                  Fetty Wap Remy Boyz
# 35                              Fifth Harmony Fetty Wap
# 36                          Fifth Harmony Ty Dolla $ign
# 37                                             Flo Rida
# 38                                 Florida Georgia Line
# 39                                            Flume kai
# 40                                               Future
# 41                                    Future The Weeknd
# 42                                    G-Eazy Bebe Rexha
# 43                                 gnash Olivia O'Brien
# 44                           Hailee Steinfeld Grey Zedd
# 45                                            James Bay
# 46                                              Jeremih
# 47                                        Justin Bieber
# 48                                        Justin Bieber
# 49                                        Justin Bieber
# 50                                    Justin Timberlake
# 51                                           Kent Jones
# 52                                          Kevin Gates
# 53                                          Kevin Gates
# 54                                               Kiiara
# 55    Lil Wayne Wiz Khalifa Imagine Dragons Logic Ty...
# 56                                         Lukas Graham
# 57                         Major Lazer Justin Bieber MØ
# 58                              Major Lazer MØ DJ Snake
# 59                                       Meghan Trainor
# Name: artist, dtype: object

# %% [markdown]
# * Acessando várias colunas

# %%
new_df[['song_name', 'artist', 'duration_ms']]
# Out:
#                                             song_name  \
# 0             Sorry - Originally performed by Beyonce
# 1                                               Hello
# 2                    Send My Love (To Your New Lover)
# 3                                  When We Were Young
# 4                                                Here
# 5                                     Dangerous Woman
# 6                                            Into You
# 7                                        Side To Side
# 8                                               Don't
# 9                                            Exchange
# 10                          This Is What You Came For
# 11                                      One Call Away
# 12         We Don't Talk Anymore (feat. Selena Gomez)
# 13                                      Back To Sleep
# 14                            Adventure Of A Lifetime
# 15                  Hymn For The Weekend - Seeb Remix
# 16                             Sit Still, Look Pretty
# 17                                          Hide Away
# 18                                              Panda
# 19                                      Tiimmy Turner
# 20                                           For Free
# 21                                             Middle
# 22                                    Let Me Love You
# 23                                  Cake By The Ocean
# 24                                      Hotline Bling
# 25                                          Controlla
# 26                                            Jumpman
# 27                                           Too Good
# 28                                          Pop Style
# 29                                          One Dance
# 30                        Broccoli (feat. Lil Yachty)
# 31                                        Ex's & Oh's
# 32                                         On My Mind
# 33                             All The Way Up (Remix)
# 34                              679 (feat. Remy Boyz)
# 35                              All In My Head (Flex)
# 36                                     Work from Home
# 37                                           My House
# 38                                           H.O.L.Y.
# 39                                  Never Be Like You
# 40                                             Wicked
# 41                                           Low Life
# 42                                     Me, Myself & I
# 43          i hate u, i love u (feat. olivia o'brien)
# 44                                           Starving
# 45                                          Let It Go
# 46                                                oui
# 47                                      Love Yourself
# 48                                              Sorry
# 49                                  What Do You Mean?
# 50  CAN'T STOP THE FEELING! (Original Song from Dr...
# 51                                         Don't Mind
# 52                                           2 Phones
# 53                                      Really Really
# 54                                               Gold
# 55  Sucker For Pain (with Wiz Khalifa, Imagine Dra...
# 56                                            7 Years
# 57              Cold Water (feat. Justin Bieber & MØ)
# 58                      Lean On (feat. MØ & DJ Snake)
# 59                                                 NO
#
#                                                artist  duration_ms
# 0                                    2016 Dynamo Hitz       232934
# 1                                               Adele       295493
# 2                                               Adele       223080
# 3                                               Adele       290907
# 4                                        Alessia Cara       199453
# 5                                       Ariana Grande       235947
# 6                                       Ariana Grande       244453
# 7                           Ariana Grande Nicki Minaj       226160
# 8                                       Bryson Tiller       198293
# 9                                       Bryson Tiller       194613
# 10                              Calvin Harris Rihanna       222160
# 11                                       Charlie Puth       194453
# 12                          Charlie Puth Selena Gomez       217707
# 13                                        Chris Brown       201253
# 14                                           Coldplay       263787
# 15                                      Coldplay Seeb       212647
# 16                                               Daya       202221
# 17                                               Daya       192376
# 18                                          Desiigner       246761
# 19                                          Desiigner       239853
# 20                                    DJ Khaled Drake       183695
# 21                          DJ Snake Bipolar Sunshine       220573
# 22                             DJ Snake Justin Bieber       205947
# 23                                               DNCE       219147
# 24                                              Drake       267067
# 25                                              Drake       245227
# 26                                       Drake Future       205879
# 27                                      Drake Rihanna       263373
# 28                                   Drake The Throne       209453
# 29                                  Drake WizKid Kyla       173987
# 30                                    DRAM Lil Yachty       225205
# 31                                          Elle King       202173
# 32                                     Ellie Goulding       213445
# 33       Fat Joe Remy Ma JAY Z French Montana InfaRed       284831
# 34                                Fetty Wap Remy Boyz       196693
# 35                            Fifth Harmony Fetty Wap       210573
# 36                        Fifth Harmony Ty Dolla $ign       214480
# 37                                           Flo Rida       192191
# 38                               Florida Georgia Line       194187
# 39                                          Flume kai       233337
# 40                                             Future       173347
# 41                                  Future The Weeknd       313547
# 42                                  G-Eazy Bebe Rexha       251467
# 43                               gnash Olivia O'Brien       251034
# 44                         Hailee Steinfeld Grey Zedd       181880
# 45                                          James Bay       260533
# 46                                            Jeremih       238320
# 47                                      Justin Bieber       233720
# 48                                      Justin Bieber       200787
# 49                                      Justin Bieber       205680
# 50                                  Justin Timberlake       236002
# 51                                         Kent Jones       198237
# 52                                        Kevin Gates       240000
# 53                                        Kevin Gates       232093
# 54                                             Kiiara       225882
# 55  Lil Wayne Wiz Khalifa Imagine Dragons Logic Ty...       243491
# 56                                       Lukas Graham       237300
# 57                       Major Lazer Justin Bieber MØ       185352
# 58                            Major Lazer MØ DJ Snake       176561
# 59                                     Meghan Trainor       213507

# %% [markdown]
# * Aplicando uma função à uma coluna

# %%
new_df['lyrics'].str.upper()
# Out:
# 0                                                   NaN
# 1     HELLO, IT'S ME I WAS WONDERING IF AFTER ALL TH...
# 2     JUST THE GUITAR. OK, COOL. THIS WAS ALL YOU, N...
# 3                                                   NaN
# 4                                                   NaN
# 5     OH, YEAH DON'T NEED PERMISSION MADE MY DECISIO...
# 6     I'M SO INTO YOU, I CAN BARELY BREATHE AND ALL ...
# 7                                                   NaN
# 8     DON'T DON'T PLAY WITH HER, DON'T BE DISHONEST ...
# 9                                                   NaN
# 10    BABY, THIS IS WHAT YOU CAME FOR LIGHTNING STRI...
# 11                                                  NaN
# 12    [CHARLIE PUTH:] WE DON'T TALK ANYMORE WE DON'T...
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18    [SPOKEN:] THIS WHAT THEY ALL BEEN WAITIN' FOR....
# 19    YEAH, YEAH, YEAH, YEAH GRRRRRAAAAH YEAH, YEAH,...
# 20                                                  NaN
# 21                                                  NaN
# 22    I USED TO BELIEVE WE WERE BURNIN' ON THE EDGE ...
# 23    OH NO SEE YOU WALKING 'ROUND LIKE IT'S A FUNER...
# 24    YOU USED TO CALL ME ON MY YOU USED TO, YOU USE...
# 25                                                  NaN
# 26    [DRAKE:] YEAH HALLOWEEN TALIBAN, TALIBAN JUMPM...
# 27    [DRAKE:] OH YEAH YEAH YEAH OH YEAH YEAH YEAH Y...
# 28                                                  NaN
# 29    [INTRO - KYLA & WIZKID:] BABY, I LIKE YOUR STY...
# 30    [D.R.A.M.:] AIN'T NO TELLING WHAT I'M FINNA BE...
# 31                                                  NaN
# 32                                                  NaN
# 33    [FAT JOE:] NOTHING CAN STOP ME, I'M ALL THE WA...
# 34                                                  NaN
# 35                                                  NaN
# 36    I AIN'T WORRIED 'BOUT NOTHIN' I AIN'T WEARIN' ...
# 37    OPEN UP THE CHAMPAGNE, POP! IT'S MY HOUSE, COM...
# 38    WHEN THE SUN HAD LEFT AND THE WINTER CAME AND ...
# 39    WHAT I WOULD DO TO TAKE AWAY THIS FEAR OF BEIN...
# 40                                                  NaN
# 41    [REFRAIN:] EVERYBODY GETTING HIGH GETTING HIGH...
# 42    [BEBE REXHA (G-EAZY):] OH, IT'S JUST ME, MYSEL...
# 43    [OLIVIA O'BRIEN:] FEELING USED BUT I'M STILL M...
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47    FOR ALL THE TIMES THAT YOU RAIN ON MY PARADE A...
# 48    YOU GOTTA GO AND GET ANGRY AT ALL OF MY HONEST...
# 49    WHAT DO YOU MEAN? OHH OHH OHH WHEN YOU NOD YOU...
# 50    I GOT THIS FEELING INSIDE MY BONES IT GOES ELE...
# 51                                                  NaN
# 52                                                  NaN
# 53                                                  NaN
# 54    ROOF IS FALLING LET ME LOVE ME FALLING I JUST ...
# 55    [DAN REYNOLDS & SAM HARRIS:] I TORTURE YOU TAK...
# 56    ONCE I WAS SEVEN YEARS OLD, MY MAMA TOLD ME "G...
# 57    [JUSTIN BIEBER:] EVERYBODY GETS HIGH SOMETIMES...
# 58                                                  NaN
# 59    I THINK IT'S SO CUTE AND I THINK IT'S SO SWEET...
# Name: lyrics, dtype: object

# %% [markdown]
# ### Acesso por linha

# %% [markdown]
# * Acessando uma linha específica

# %%
new_df.loc[50]
# Out:
# id_billboard                                                        9
# song_name           CAN'T STOP THE FEELING! (Original Song from Dr...
# artist                                              Justin Timberlake
# lyrics              I got this feeling inside my bones It goes ele...
# danceability                                                    0.667
# energy                                                           0.83
# loudness                                                       -5.715
# speechiness                                                    0.0749
# acousticness                                                   0.0123
# instrumentalness                                                    0
# liveness                                                        0.191
# valence                                                         0.716
# duration_ms                                                    236002
# Name: 50, dtype: object

# %% [markdown]
# * Acessando uma ou mais linhas a partir de uma consulta

# %%
new_df[new_df['song_name'] == 'Here']
# Out:
#    id_billboard song_name        artist lyrics  danceability  energy  \
# 4            39      Here  Alessia Cara    NaN         0.376    0.81
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 4    -4.003        0.166        0.0844               0.0     0.073    0.334
#
#    duration_ms
# 4       199453

# %%
new_df['lyrics'].str.upper()[1]
# Out:
# "HELLO, IT'S ME I WAS WONDERING IF AFTER ALL THESE YEARS YOU'D LIKE TO MEET TO GO OVER EVERYTHING THEY SAY THAT TIME'S SUPPOSED TO HEAL YA BUT I AIN'T DONE MUCH HEALING HELLO, CAN YOU HEAR ME? I'M IN CALIFORNIA DREAMING ABOUT WHO WE USED TO BE WHEN WE WERE YOUNGER AND FREE I'VE FORGOTTEN HOW IT FELT BEFORE THE WORLD FELL AT OUR FEET THERE'S SUCH A DIFFERENCE BETWEEN US AND A MILLION MILES HELLO FROM THE OTHER SIDE I MUST HAVE CALLED A THOUSAND TIMES TO TELL YOU I'M SORRY FOR EVERYTHING THAT I'VE DONE BUT WHEN I CALL YOU NEVER SEEM TO BE HOME HELLO FROM THE OUTSIDE AT LEAST I CAN SAY THAT I'VE TRIED TO TELL YOU I'M SORRY FOR BREAKING YOUR HEART BUT IT DON'T MATTER, IT CLEARLY DOESN'T TEAR YOU APART ANYMORE HELLO, HOW ARE YOU? IT'S SO TYPICAL OF ME TO TALK ABOUT MYSELF, I'M SORRY I HOPE THAT YOU'RE WELL DID YOU EVER MAKE IT OUT OF THAT TOWN WHERE NOTHING EVER HAPPENED? IT'S NO SECRET THAT THE BOTH OF US ARE RUNNING OUT OF TIME SO HELLO FROM THE OTHER SIDE (OTHER SIDE) I MUST HAVE CALLED A THOUSAND TIMES (THOUSAND TIMES) TO TELL YOU I'M SORRY FOR EVERYTHING THAT I'VE DONE BUT WHEN I CALL YOU NEVER SEEM TO BE HOME HELLO FROM THE OUTSIDE (OUTSIDE) AT LEAST I CAN SAY THAT I'VE TRIED (I'VE TRIED) TO TELL YOU I'M SORRY FOR BREAKING YOUR HEART BUT IT DON'T MATTER, IT CLEARLY DOESN'T TEAR YOU APART ANYMORE (HIGHS, HIGHS, HIGHS, HIGHS, LOWS, LOWS, LOWS, LOWS) ANYMORE (HIGHS, HIGHS, HIGHS, HIGHS, LOWS, LOWS, LOWS, LOWS) ANYMORE (HIGHS, HIGHS, HIGHS, HIGHS, LOWS, LOWS, LOWS, LOWS) ANYMORE (HIGHS, HIGHS, HIGHS, HIGHS, LOWS, LOWS, LOWS, LOWS) ANYMORE HELLO FROM THE OTHER SIDE (OTHER SIDE) I MUST HAVE CALLED A THOUSAND TIMES (THOUSAND TIMES) TO TELL YOU I'M SORRY FOR EVERYTHING THAT I'VE DONE BUT WHEN I CALL YOU NEVER SEEM TO BE HOME HELLO FROM THE OUTSIDE (OUTSIDE) AT LEAST I CAN SAY THAT I'VE TRIED (I'VE TRIED) TO TELL YOU I'M SORRY FOR BREAKING YOUR HEART BUT IT DON'T MATTER, IT CLEARLY DOESN'T TEAR YOU APART ANYMORE"

# %%
new_df[new_df['duration_ms'] >= 280000]
# Out:
#     id_billboard               song_name  \
# 1              7                   Hello
# 3             83      When We Were Young
# 33            87  All The Way Up (Remix)
# 41            30                Low Life
#
#                                           artist  \
# 1                                          Adele
# 3                                          Adele
# 33  Fat Joe Remy Ma JAY Z French Montana InfaRed
# 41                             Future The Weeknd
#
#                                                lyrics  danceability  energy  \
# 1   Hello, it's me I was wondering if after all th...         0.481   0.451
# 3                                                 NaN         0.381   0.594
# 33  [Fat Joe:] Nothing can stop me, I'm all the wa...         0.564   0.717
# 41  [Refrain:] Everybody getting high Getting high...         0.722   0.331
#
#     loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 1     -6.095       0.0347         0.336             0.000    0.0872    0.287
# 3     -5.970       0.0486         0.348             0.000    0.0925    0.275
# 33    -6.403       0.3970         0.097             0.000    0.4930    0.421
# 41    -7.789       0.0725         0.337             0.283    0.1460    0.102
#
#     duration_ms
# 1        295493
# 3        290907
# 33       284831
# 41       313547

# %% [markdown]
# ### Criação de novas colunas

# %%
new_df['duration_label'] = new_df['duration_ms'].map(lambda x: "short" if x <= 200000 else "long")
new_df.sample(10)
# Out:
#     id_billboard                                          song_name  \
# 33            87                             All The Way Up (Remix)
# 59            45                                                 NO
# 26            37                                            Jumpman
# 3             83                                 When We Were Young
# 45            44                                          Let It Go
# 51            48                                         Don't Mind
# 0             71            Sorry - Originally performed by Beyonce
# 55            68  Sucker For Pain (with Wiz Khalifa, Imagine Dra...
# 8             35                                              Don't
# 54            52                                               Gold
#
#                                                artist  \
# 33       Fat Joe Remy Ma JAY Z French Montana InfaRed
# 59                                     Meghan Trainor
# 26                                       Drake Future
# 3                                               Adele
# 45                                          James Bay
# 51                                         Kent Jones
# 0                                    2016 Dynamo Hitz
# 55  Lil Wayne Wiz Khalifa Imagine Dragons Logic Ty...
# 8                                       Bryson Tiller
# 54                                             Kiiara
#
#                                                lyrics  danceability  energy  \
# 33  [Fat Joe:] Nothing can stop me, I'm all the wa...         0.564   0.717
# 59  I think it's so cute and I think it's so sweet...         0.557   0.801
# 26  [Drake:] Yeah Halloween Taliban, taliban Jumpm...         0.853   0.558
# 3                                                 NaN         0.381   0.594
# 45                                                NaN         0.546   0.311
# 51                                                NaN         0.464   0.771
# 0                                                 NaN         0.699   0.526
# 55  [Dan Reynolds & Sam Harris:] I torture you Tak...         0.502   0.786
# 8   Don't Don't play with her, don't be dishonest ...         0.765   0.356
# 54  Roof is falling let me love me falling I just ...         0.600   0.412
#
#     loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 33    -6.403       0.3970       0.09700          0.000000    0.4930    0.421
# 59    -3.602       0.2180       0.01250          0.000002    0.7370    0.645
# 26    -7.448       0.2020       0.04620          0.000000    0.3410    0.666
# 3     -5.970       0.0486       0.34800          0.000000    0.0925    0.275
# 45   -10.396       0.0288       0.81800          0.000017    0.1070    0.263
# 51    -4.503       0.3360       0.02350          0.000000    0.0630    0.678
# 0    -13.514       0.0373       0.00101          0.001650    0.1930    0.148
# 55    -4.378       0.3170       0.25500          0.000000    0.6500    0.734
# 8     -5.556       0.1960       0.22200          0.000000    0.0963    0.191
# 54    -9.343       0.3440       0.61500          0.002500    0.1340    0.409
#
#     duration_ms duration_label
# 33       284831           long
# 59       213507           long
# 26       205879           long
# 3        290907           long
# 45       260533           long
# 51       198237          short
# 0        232934           long
# 55       243491           long
# 8        198293          short
# 54       225882           long
